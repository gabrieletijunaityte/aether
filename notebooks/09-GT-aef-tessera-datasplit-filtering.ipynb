# %%
import glob
import os

import pandas as pd
import torch

os.chdir("..")
os.getcwd()

# %%
# Check how do aef and tessera files overlap
paths = glob.glob("data/s2bms/eo/aef/*.npy")
aef = []
for p in paths:
    aef.append(os.path.basename(p).split(".")[0].split("-")[-1])

paths = glob.glob("data/s2bms/eo/tessera/*.npy")
tsr = []
for p in paths:
    tsr.append(os.path.basename(p).split(".")[0].split("-")[-1])

common = list(set(tsr) & set(aef))

tsr_left = list(set(tsr) - set(common))  # None
aef_left = list(set(aef) - set(common))  # 12

# Filter out unlabelled data
tsr_left = {i for i in tsr_left if "sample" not in i}
aef_left = {i for i in aef_left if "sample" not in i}

print("Tessera:", tsr_left)
print("AlphaEarth:", aef_left)

# %%
# Load in original datasplit file
pth = "data/s2bms/splits/split_indices_s2bms_2024-08-14-1459.pth"
split_indices = torch.load(pth, weights_only=False)

# %%
# Print data split sizes
s = 0
print("Before cleaning:")
for k, v in split_indices.items():
    if not k == "clusters":
        print(k, len(v))
        s += len(v)

# %%
# Filter out remaining aef but missing tessera tiles form val and test splits

aef_left_str = [f"UKBMS_loc-{idx}" for idx in aef_left]

split_indices["val_indices"] = split_indices["val_indices"][
    ~split_indices["val_indices"].isin(aef_left_str)
]
split_indices["test_indices"] = split_indices["test_indices"][
    ~split_indices["test_indices"].isin(aef_left_str)
]

print("After test/val cleaning:")
for k, v in split_indices.items():
    if not k == "clusters":
        print(k, len(v))
        s += len(v)

if os.path.exists("data/s2bms/splits/s2bms_union_val_test.pth"):
    print("Already saved")
else:
    torch.save(
        split_indices,
        "data/s2bms/splits/s2bms_union_val_test.pth",
    )

# %%
# Visualise data split
df = pd.read_csv("data/s2bms/model_ready_s2bms.csv")

train_idx = split_indices["train_indices"]
train_df = df[df["name_loc"].isin(map(str, train_idx))]

val_idx = split_indices["val_indices"]
val_df = df[df["name_loc"].isin(map(str, val_idx))]

test_idx = split_indices["test_indices"]
test_df = df[df["name_loc"].isin(map(str, test_idx))]

# %%
import folium

m = folium.Map(location=[df.lat.mean(), df.lon.mean()], zoom_start=3)

# Train = blue
for _, row in train_df.iterrows():
    folium.CircleMarker(location=[row.lat, row.lon], radius=2, color="blue", fill=True).add_to(m)

# Val = orange
for _, row in val_df.iterrows():
    folium.CircleMarker(location=[row.lat, row.lon], radius=2, color="orange", fill=True).add_to(m)

# Test = red
for _, row in test_df.iterrows():
    folium.CircleMarker(location=[row.lat, row.lon], radius=2, color="red", fill=True).add_to(m)

m

# %% [markdown]
# # Re-do Unlabelled split

# %%
df_unlabelled = pd.read_csv("data/s2bms/model_ready_s2bms-unlabelled-20260529.csv")
df_unlabelled = df_unlabelled[df_unlabelled.split == "train"]

train_unlabelled = list(df_unlabelled.name_loc)

# %%
pth = "data/s2bms/splits/split_indices_s2bms+s2bms-unlabelled-20260529_2026-05-29-1438.pth"
split_indices = torch.load(pth, weights_only=False)

print("Before test/val/train:")
s = 0
for k, v in split_indices.items():
    if not k == "clusters":
        print(k, len(v))
        s += len(v)

# %%
split_indices["train_indices"] = pd.Series(
    [i for i in list(split_indices["train_indices"]) if i in train_unlabelled or "UKBMS" in i]
)

# %%
val_test_indices = torch.load(
    "data/s2bms/splits/s2bms_union_val_test.pth",
    weights_only=False,
)

# %%
split_indices["val_indices"] = pd.Series(
    [i for i in list(val_test_indices["val_indices"]) if "UKBMS" in i]
)
split_indices["test_indices"] = pd.Series(
    [i for i in list(val_test_indices["test_indices"]) if "UKBMS" in i]
)

# %%
print("After test/val/train:")
s = 0
for k, v in split_indices.items():
    if not k == "clusters":
        print(k, len(v))
        s += len(v)

# %%
if not os.path.exists("data/s2bms/splits/s2bms_unlabelled_union_val_test.pth"):
    torch.save(
        split_indices,
        "data/s2bms/splits/s2bms_unlabelled_union_val_test.pth",
    )
else:
    print("Already saved")

# %%
# Visualise data split
df_merged = pd.concat([df, df_unlabelled])

train_idx = split_indices["train_indices"]
train_df = df_merged[df_merged["name_loc"].isin(map(str, train_idx))]

val_idx = split_indices["val_indices"]
val_df = df_merged[df_merged["name_loc"].isin(map(str, val_idx))]

test_idx = split_indices["test_indices"]
test_df = df_merged[df_merged["name_loc"].isin(map(str, test_idx))]

# %%
m = folium.Map(location=[df.lat.mean(), df.lon.mean()], zoom_start=3)

# Train = blue
for _, row in train_df.iterrows():
    folium.CircleMarker(location=[row.lat, row.lon], radius=2, color="blue", fill=True).add_to(m)

# Val = orange
for _, row in val_df.iterrows():
    folium.CircleMarker(location=[row.lat, row.lon], radius=2, color="orange", fill=True).add_to(m)

# Test = red
for _, row in test_df.iterrows():
    folium.CircleMarker(location=[row.lat, row.lon], radius=2, color="red", fill=True).add_to(m)

m

# %% [markdown]
# # SatBIRD

# %%
df = pd.read_csv("data/satbird-USA-summer/eo/aef-satbird-usa-summer_average-128.csv")
list_128 = list(df.name_loc)
len(list_128)

# %%
df = pd.read_csv("data/satbird-USA-summer/eo/aef-satbird-usa-summer_average-256.csv")
list_256 = list(df.name_loc)
len(list_256)

# %%
complete = set(list_128) & set(list_256)
len(complete)

# %%
# Load in original datasplit file
pth = "data/satbird-USA-summer/splits/split_indices_satbird-USA-summer.pth"
split_indices = torch.load(pth, weights_only=False)

# %%
# Print data split sizes
s = 0
print("Before cleaning:")
for k, v in split_indices.items():
    if not k == "clusters":
        print(k, len(v))
        s += len(v)

# %%
holdout_pool = set(split_indices["val_indices"]) | set(split_indices["test_indices"])
clean_holdout = sorted(holdout_pool & complete)

# %%
complete = set(list_128) & set(list_256)

split_indices["val_indices"] = split_indices["val_indices"][
    split_indices["val_indices"].isin(complete)
]
split_indices["test_indices"] = split_indices["test_indices"][
    split_indices["test_indices"].isin(complete)
]

print("After cleaning:")
for k, v in split_indices.items():
    if k != "clusters":
        print(k, len(v))


if os.path.exists("data/satbird-USA-summer/splits/satbird-USA-summer_aef_union_val_test.pth"):
    print("Already saved")
else:
    torch.save(
        split_indices, "data/satbird-USA-summer/splits/satbird-USA-summer_aef_union_val_test.pth"
    )

# %% [markdown]
# # SatBIRD with LC

# %%
df = pd.read_csv("data/satbird-USA-summer/model_ready_satbird-USA-summer_with_lc.csv")
# Load in original datasplit file
pth = "data/satbird-USA-summer/splits/satbird-USA-summer_aef_union_val_test.pth"
split_indices = torch.load(pth, weights_only=False)

# %%
# Print data split sizes
s = 0
print("Before cleaning:")
for k, v in split_indices.items():
    if not k == "clusters":
        print(k, len(v))
        s += len(v)

# %%
lost = [
    "L1009496",
    "L10114938",
    "L10132889",
    "L11031849",
    "L1118302",
    "L1146796",
    "L1251601",
    "L127592",
    "L1307647",
    "L1369348",
    "L14523566",
    "L1518478",
    "L152895",
    "L15353768",
    "L158896",
    "L1604677",
    "L1956687",
    "L2034763",
    "L2228716",
    "L2259286",
    "L283714",
    "L2844634",
    "L295118",
    "L305303",
    "L3152071",
    "L326867",
    "L3450545",
    "L3742591",
    "L3745085",
    "L3749476",
    "L4072256",
    "L4080453",
    "L464304",
    "L4700891",
    "L4713292",
    "L504330",
    "L5510587",
    "L5981406",
    "L611593",
    "L6559937",
    "L6991513",
    "L7578632",
    "L7664384",
    "L7971008",
    "L8334036",
    "L913756",
    "L917353",
    "L9642235",
]

# %%
split_indices["val_indices"] = split_indices["val_indices"][
    ~split_indices["val_indices"].isin(lost)
]
split_indices["test_indices"] = split_indices["test_indices"][
    ~split_indices["test_indices"].isin(lost)
]
split_indices["train_indices"] = split_indices["train_indices"][
    ~split_indices["train_indices"].isin(lost)
]

# %%
for i in lost:
    if i in split_indices["val_indices"].values:
        print(i, "in val")
    if i in split_indices["test_indices"].values:
        print(i, "in test")

# %%
print("After cleaning:")
for k, v in split_indices.items():
    if k != "clusters":
        print(k, len(v))


if os.path.exists("data/satbird-USA-summer/splits/satbird-USA-summer_aef_union_val_test_lc.pth"):
    print("Already saved")
else:
    torch.save(
        split_indices,
        "data/satbird-USA-summer/splits/satbird-USA-summer_aef_union_val_test_lc.pth",
    )

# %%
v
